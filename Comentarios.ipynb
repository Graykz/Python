# %% [markdown]
# <a href="https://colab.research.google.com/github/Graykz/Python/blob/main/Comentarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Este es un comentario en Python
print ("Hola mundo!")
# Out:
# Hola mundo!

# %% [markdown]
# Este comentario es en colab. Los comentarios dentro del codigo son para escribir cosas del codigo. Los comentarios fuera del codigo (texto) son para notas fuera del codigo. Para los comentarios dentro del codigo puedo usar numeral o triple comillas para el caso de salto en linea.

# %%
sin numeral da error
# Out:
#   File "<ipython-input-2-b4469cab31c3>", line 1
#     sin numeral da error
#         ^
# SyntaxError: invalid syntax

# %%
"""
Este
comentario
tiene saltos en linea
"""
print ("Un mensaje por consola de Python")
# Out:
# Un mensaje por consola de Python

# %% [markdown]
# ![espacio-galaxia-fondo-generativo-ai.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Aqui escribimos texto en colab.
